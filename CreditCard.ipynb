# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]
# Out:
# C:\Users\Wellborn\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Exploration

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0,color='red')
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# ### Preparing the data

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
X_train.shape
# Out:
# (227451, 29)

# %% [markdown]
# ## Building the model

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.8184 - accuracy: 0.5743 - val_loss: 0.7965 - val_accuracy: 0.6293
# Epoch 2/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7521 - accuracy: 0.6406 - val_loss: 0.7711 - val_accuracy: 0.6506
# Epoch 3/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7330 - accuracy: 0.6517 - val_loss: 0.7573 - val_accuracy: 0.6486
# Epoch 4/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7248 - accuracy: 0.6602 - val_loss: 0.7529 - val_accuracy: 0.6721
# Epoch 5/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7205 - accuracy: 0.6669 - val_loss: 0.7500 - val_accuracy: 0.6769
# Epoch 6/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7169 - accuracy: 0.6736 - val_loss: 0.7465 - val_accuracy: 0.6797
# Epoch 7/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7147 - accuracy: 0.6788 - val_loss: 0.7448 - val_accuracy: 0.6896
# Epoch 8/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7130 - accuracy: 0.6835 - val_loss: 0.7441 - val_accuracy: 0.6850
# Epoch 9/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7115 - accuracy: 0.6868 - val_loss: 0.7456 - val_accuracy: 0.6876
# Epoch 10/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7106 - accuracy: 0.6886 - val_loss: 0.7453 - val_accuracy: 0.6877
# Epoch 11/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7097 - accuracy: 0.6890 - val_loss: 0.7437 - val_accuracy: 0.6923
# Epoch 12/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7093 - accuracy: 0.6894 - val_loss: 0.7417 - val_accuracy: 0.6934
# Epoch 13/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7091 - accuracy: 0.6891 - val_loss: 0.7429 - val_accuracy: 0.6935
# Epoch 14/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7087 - accuracy: 0.6886 - val_loss: 0.7435 - val_accuracy: 0.6957
# Epoch 15/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7083 - accuracy: 0.6879 - val_loss: 0.7443 - val_accuracy: 0.6964
# Epoch 16/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7084 - accuracy: 0.6868 - val_loss: 0.7463 - val_accuracy: 0.6929
# Epoch 17/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7076 - accuracy: 0.6884 - val_loss: 0.7403 - val_accuracy: 0.6870
# Epoch 18/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7075 - accuracy: 0.6895 - val_loss: 0.7413 - val_accuracy: 0.7009
# Epoch 19/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7073 - accuracy: 0.6899 - val_loss: 0.7403 - val_accuracy: 0.6961
# Epoch 20/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7067 - accuracy: 0.6915 - val_loss: 0.7394 - val_accuracy: 0.6941
# Epoch 21/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7066 - accuracy: 0.6928 - val_loss: 0.7399 - val_accuracy: 0.6964
# Epoch 22/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.7064 - accuracy: 0.6919 - val_loss: 0.7407 - val_accuracy: 0.6946
# Epoch 23/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7060 - accuracy: 0.6934 - val_loss: 0.7392 - val_accuracy: 0.6800
# Epoch 24/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7061 - accuracy: 0.6926 - val_loss: 0.7397 - val_accuracy: 0.7011
# Epoch 25/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7056 - accuracy: 0.6943 - val_loss: 0.7423 - val_accuracy: 0.6988
# Epoch 26/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7053 - accuracy: 0.6946 - val_loss: 0.7388 - val_accuracy: 0.6949
# Epoch 27/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7058 - accuracy: 0.6942 - val_loss: 0.7385 - val_accuracy: 0.7006
# Epoch 28/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7055 - accuracy: 0.6953 - val_loss: 0.7412 - val_accuracy: 0.6963
# Epoch 29/100
# 7108/7108 [==============================] - 14s 2ms/step - loss: 0.7055 - accuracy: 0.6957 - val_loss: 0.7382 - val_accuracy: 0.6983
# Epoch 30/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7052 - accuracy: 0.6960 - val_loss: 0.7393 - val_accuracy: 0.6902
# Epoch 31/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7050 - accuracy: 0.6966 - val_loss: 0.7377 - val_accuracy: 0.7033
# Epoch 32/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7051 - accuracy: 0.6964 - val_loss: 0.7389 - val_accuracy: 0.6975
# Epoch 33/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7051 - accuracy: 0.6962 - val_loss: 0.7376 - val_accuracy: 0.7026
# Epoch 34/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7043 - accuracy: 0.6966 - val_loss: 0.7378 - val_accuracy: 0.7056
# Epoch 35/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7043 - accuracy: 0.6968 - val_loss: 0.7398 - val_accuracy: 0.7008
# Epoch 36/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7040 - accuracy: 0.6965 - val_loss: 0.7373 - val_accuracy: 0.6976
# Epoch 37/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7038 - accuracy: 0.6968 - val_loss: 0.7364 - val_accuracy: 0.7067
# Epoch 38/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7037 - accuracy: 0.6963 - val_loss: 0.7372 - val_accuracy: 0.7053
# Epoch 39/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7038 - accuracy: 0.6956 - val_loss: 0.7367 - val_accuracy: 0.7012
# Epoch 40/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7036 - accuracy: 0.6968 - val_loss: 0.7384 - val_accuracy: 0.7003
# Epoch 41/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7037 - accuracy: 0.6971 - val_loss: 0.7368 - val_accuracy: 0.7042
# Epoch 42/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7035 - accuracy: 0.6966 - val_loss: 0.7364 - val_accuracy: 0.7049
# Epoch 43/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7034 - accuracy: 0.6971 - val_loss: 0.7375 - val_accuracy: 0.6990
# Epoch 44/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7035 - accuracy: 0.6958 - val_loss: 0.7414 - val_accuracy: 0.6968
# Epoch 45/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7034 - accuracy: 0.6968 - val_loss: 0.7382 - val_accuracy: 0.6993
# Epoch 46/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7032 - accuracy: 0.6975 - val_loss: 0.7378 - val_accuracy: 0.7023
# Epoch 47/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7034 - accuracy: 0.6970 - val_loss: 0.7363 - val_accuracy: 0.7024
# Epoch 48/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7032 - accuracy: 0.6969 - val_loss: 0.7372 - val_accuracy: 0.7011
# Epoch 49/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7032 - accuracy: 0.6967 - val_loss: 0.7366 - val_accuracy: 0.7051
# Epoch 50/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7029 - accuracy: 0.6972 - val_loss: 0.7371 - val_accuracy: 0.7061
# Epoch 51/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7032 - accuracy: 0.6967 - val_loss: 0.7389 - val_accuracy: 0.7017
# Epoch 52/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7034 - accuracy: 0.6966 - val_loss: 0.7383 - val_accuracy: 0.7014
# Epoch 53/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7027 - accuracy: 0.6969 - val_loss: 0.7365 - val_accuracy: 0.7055
# Epoch 54/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7030 - accuracy: 0.6968 - val_loss: 0.7378 - val_accuracy: 0.6970
# Epoch 55/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7028 - accuracy: 0.6971 - val_loss: 0.7424 - val_accuracy: 0.6984
# Epoch 56/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7028 - accuracy: 0.6974 - val_loss: 0.7368 - val_accuracy: 0.7050
# Epoch 57/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7027 - accuracy: 0.6975 - val_loss: 0.7373 - val_accuracy: 0.6957
# Epoch 58/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7027 - accuracy: 0.6982 - val_loss: 0.7369 - val_accuracy: 0.7036
# Epoch 59/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7025 - accuracy: 0.6975 - val_loss: 0.7365 - val_accuracy: 0.7028
# Epoch 60/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7025 - accuracy: 0.6978 - val_loss: 0.7373 - val_accuracy: 0.7064
# Epoch 61/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7026 - accuracy: 0.6976 - val_loss: 0.7367 - val_accuracy: 0.7062
# Epoch 62/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7026 - accuracy: 0.6987 - val_loss: 0.7364 - val_accuracy: 0.7008
# Epoch 63/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7026 - accuracy: 0.6981 - val_loss: 0.7370 - val_accuracy: 0.7060
# Epoch 64/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7024 - accuracy: 0.6989 - val_loss: 0.7405 - val_accuracy: 0.6944
# Epoch 65/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7022 - accuracy: 0.6993 - val_loss: 0.7373 - val_accuracy: 0.7019
# Epoch 66/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7024 - accuracy: 0.7002 - val_loss: 0.7373 - val_accuracy: 0.6936
# Epoch 67/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7021 - accuracy: 0.6995 - val_loss: 0.7363 - val_accuracy: 0.7040
# Epoch 68/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7022 - accuracy: 0.6996 - val_loss: 0.7361 - val_accuracy: 0.7124
# Epoch 69/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7020 - accuracy: 0.7017 - val_loss: 0.7355 - val_accuracy: 0.6925
# Epoch 70/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7018 - accuracy: 0.7006 - val_loss: 0.7357 - val_accuracy: 0.7060
# Epoch 71/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7018 - accuracy: 0.7012 - val_loss: 0.7380 - val_accuracy: 0.6934
# Epoch 72/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7018 - accuracy: 0.7013 - val_loss: 0.7352 - val_accuracy: 0.7071
# Epoch 73/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7018 - accuracy: 0.7014 - val_loss: 0.7358 - val_accuracy: 0.7077
# Epoch 74/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7018 - accuracy: 0.7019 - val_loss: 0.7345 - val_accuracy: 0.7091
# Epoch 75/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7018 - accuracy: 0.7017 - val_loss: 0.7371 - val_accuracy: 0.6996
# Epoch 76/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7018 - accuracy: 0.7022 - val_loss: 0.7357 - val_accuracy: 0.7038
# Epoch 77/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7013 - accuracy: 0.7024 - val_loss: 0.7356 - val_accuracy: 0.7057
# Epoch 78/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7017 - accuracy: 0.7020 - val_loss: 0.7362 - val_accuracy: 0.7058
# Epoch 79/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7017 - accuracy: 0.7030 - val_loss: 0.7356 - val_accuracy: 0.7075
# Epoch 80/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7016 - accuracy: 0.7017 - val_loss: 0.7356 - val_accuracy: 0.6977
# Epoch 81/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7019 - accuracy: 0.7029 - val_loss: 0.7364 - val_accuracy: 0.6930
# Epoch 82/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7016 - accuracy: 0.7023 - val_loss: 0.7356 - val_accuracy: 0.7117
# Epoch 83/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7014 - accuracy: 0.7030 - val_loss: 0.7363 - val_accuracy: 0.7063
# Epoch 84/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7016 - accuracy: 0.7029 - val_loss: 0.7382 - val_accuracy: 0.7033
# Epoch 85/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7016 - accuracy: 0.7022 - val_loss: 0.7361 - val_accuracy: 0.7026
# Epoch 86/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7013 - accuracy: 0.7037 - val_loss: 0.7359 - val_accuracy: 0.7069
# Epoch 87/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7017 - accuracy: 0.7018 - val_loss: 0.7366 - val_accuracy: 0.7048
# Epoch 88/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7017 - accuracy: 0.7029 - val_loss: 0.7340 - val_accuracy: 0.7101
# Epoch 89/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7015 - accuracy: 0.7030 - val_loss: 0.7354 - val_accuracy: 0.7041
# Epoch 90/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7014 - accuracy: 0.7031 - val_loss: 0.7362 - val_accuracy: 0.7066
# Epoch 91/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7017 - accuracy: 0.7027 - val_loss: 0.7352 - val_accuracy: 0.7023
# Epoch 92/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7014 - accuracy: 0.7028 - val_loss: 0.7357 - val_accuracy: 0.6999
# Epoch 93/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7013 - accuracy: 0.7030 - val_loss: 0.7373 - val_accuracy: 0.7056
# Epoch 94/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7013 - accuracy: 0.7028 - val_loss: 0.7361 - val_accuracy: 0.7013
# Epoch 95/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7014 - accuracy: 0.7033 - val_loss: 0.7349 - val_accuracy: 0.7067
# Epoch 96/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7013 - accuracy: 0.7027 - val_loss: 0.7355 - val_accuracy: 0.7032
# Epoch 97/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7015 - accuracy: 0.7036 - val_loss: 0.7361 - val_accuracy: 0.7012
# Epoch 98/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7011 - accuracy: 0.7032 - val_loss: 0.7347 - val_accuracy: 0.7127
# Epoch 99/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7012 - accuracy: 0.7036 - val_loss: 0.7361 - val_accuracy: 0.6913
# Epoch 100/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7011 - accuracy: 0.7029 - val_loss: 0.7367 - val_accuracy: 0.6888

# %%
autoencoder = load_model('model.h5')

# %% [markdown]
# ### Evaluation

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
# Out:
# 1781/1781 [==============================] - 3s 1ms/step

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.733186      0.001720
# std                3.420740      0.041443
# min                0.035475      0.000000
# 25%                0.243338      0.000000
# 50%                0.388745      0.000000
# 75%                0.611041      0.000000
# max              254.981955      1.000000

# %% [markdown]
# ### Reconstruction error without fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %% [markdown]
# ### Reconstruction error with fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# ### Precision vs Recall

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %%
threshold = 2.9

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
